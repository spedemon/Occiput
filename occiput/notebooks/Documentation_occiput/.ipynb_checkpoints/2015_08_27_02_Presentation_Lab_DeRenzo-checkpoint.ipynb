# %% [markdown]
# [Index](Index.ipynb) - [Back](2015_08_27_03_Presentation_Lab_Cylinder.ipynb) - [Next](2015_08_27_03_Presentation_Lab_Brain.ipynb)

# %% [markdown]
# # DE RENZO PHANTOM acquired on Siemens Biograph mMR

# %%
import occiput
from occiput.Reconstruction.PET.PET_scanners import Biograph_mMR
from occiput.DataSources.FileSources import import_interfile_volume

# %%
pet = occiput.Reconstruction.PET.PET_Static_Scan()

# %%
pet.set_scanner(Biograph_mMR)

# %%
pet.use_compression(False)

# %% [markdown]
# LOAD MEASUREMENT DATA - 10 MINS

# %%
listmode = 0
if (listmode == 1):
    pet.import_listmode('../../data/PET_data/scans/2015_05_20_deRenzo/listmode_and_sensitivity/PET_ACQ_1014_20150520090638-0.l.hdr')
    pet.export_prompts('../../data/PET_data/scans/2015_05_20_deRenzo/occiput/prompts.h5')
    pet.export_randoms('../../data/PET_data/scans/2015_05_20_deRenzo/occiput/randoms.h5')
else:
    pet.import_prompts('../../data/PET_data/scans/2015_05_20_deRenzo/occiput/prompts.h5')
    pet.import_randoms('../../data/PET_data/scans/2015_05_20_deRenzo/occiput/randoms.h5')
# Out:
# Uncompression done
# Uncompression done

# %%
pet.use_compression(False)

# %%
# Import sensitivity
pet.import_sensitivity('../../data/PET_data/sensitivity/2015_05_20_derenzo/norm3d_00.h33')
#pet.import_sensitivity('../../data/PET_data/scans/2014_09_05_brain_nf_014_base/listmode_and_sensitivity/norm3d_00.h33')

# %%
pet.use_compression(False)

# %%
figure(figsize=[16,6])
subplot(1,4,1); imshow(pet.prompts.to_nd_array()[0,5,:,:].transpose())
subplot(1,4,2); imshow(pet.prompts.to_nd_array()[0,0,:,:].transpose())
subplot(1,4,3); imshow(pet.sensitivity.to_nd_array()[0,5,:,:].transpose())
subplot(1,4,4); imshow(pet.sensitivity.to_nd_array()[0,0,:,:].transpose())

# %%
pet.set_activity_shape([128,128,128])
pet.set_activity_size([128*pet.activity_size[0]/344.0,128*pet.activity_size[1]/344.0,128*pet.activity_size[2]/127.0])

# %% [markdown]
# ITERATIVE RECONSTRUCTION

# %%
activity_recon = pet.osem_reconstruction(iterations=4, attenuation=None, subset_mode="ordered_axial", subset_size=12)
# Out:
# 0.0 / 100
# Reconstructing
# 25.0 / 100
# 50.0 / 100
# 75.0 / 100
# 100.0 / 100
# 100.0 / 100

# %%
activity_recon.save_to_file('../../data/PET_data/scans/2015_05_20_derenzo/occiput/activity_recon.nii')

# %%
from occiput.DataSources.FileSources import import_interfile_volume
#activity_recon_Siemens = ('../../data/e_7_recon/2015_05_20_deRenzo/reconstruction_no_att/de_renzo_n_000_000.v.hdr')

# %%
figure(figsize=[16,9])
subplot(1,2,1); imshow(30000*activity_recon.data[60:272,60:272,64],vmax = 100, interpolation='nearest')
#subplot(1,2,2); imshow(activity_recon_Siemens.data[60:272,60:272,64],vmax = 5000, interpolation='nearest')

# %% [markdown]
# [Index](Index.ipynb) - [Back](2015_08_27_03_Presentation_Lab_Cylinder.ipynb) - [Next](2015_08_27_03_Presentation_Lab_Brain.ipynb)
